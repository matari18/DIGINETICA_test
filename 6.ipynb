# %% [markdown]
# ### Анализ ответа API
#
# Дан запрос к API:
#
# ```
# <https://recs.diginetica.net/recs?apiKey=3847X11479&placements=item_page.alternatives%7Citem_page.cross_sell&showOnlyAvailable=true&productId=19760302811&fullData=true>
#
# ```
#
# ### Ожидания:
#
# - Проанализируйте ответ API.
# - Опишите, что можно узнать о первом товаре из предоставленного ответа.

# %% [markdown]
# ### Результат анализа:
#
# Судя по всему, запрос получает список рекомендаций для продукта `productId`=19760302811
#
# Ответ API представляет собой json, который содержит:
# * `placements` - список
# * `status` - строка, в данном случае "ok"
# * `message` - строка, в данном случае пустая
#
# Структура каждого элемента из `placements` представляет собой словарь со следующими ключами:
# * `strategyMessage` - строка, например "похожие товары"
# * `placement` - строка, напрмиер "item_page.alternatives"
# * `products` - список продуктов для рекомендации
# * `strategyName` - название стратегии
# * `responseMessages` - список строк ответов
#
# Элементы из `products` представляют собой словари со следующей структурой:
# * `trackingId` - идентификатор
# * `externalId` - внешний идентификатор
# * `groupId` - идентификатор группы
# * `name` - название
# * `price` - цена
# * `rating` - рейтинг
# * `totalRatings` - количество оценок
# * `brand` - название бренда
# * `linkUrl` - ссылка на товар
# * `imageUrl` - ссылка на изображение
# * `attributes` - словарь аттрибутов
#   * `new` - флаг новизны
#   * `adultgood` - вероятно, флаг, преднозначен ли товар для взрослых
#   * `group_sku` - идентификатор группы
# * `productSkus` - список продуктовых идентификаторов
# * `categories` - список категорий
#
# Элемент списка productSkus представляет собой словарь:
# * `id` - уникальный идентификатор
# * `available` - флаг доступности
# * `name` - название
# * `price` - цена
# * `attributes` - словарь аттрибутов
# * `link_url` - ссылка на товар
# * `image_url` - ссылка на изображение
#
# Элемент списка categories представляет собой словарь:
# * `id` - уникальный идентификатор
# * `name` - название
# * `direct` - флаг
# * `link_url` - ссылка на товар
# * `image_url` - ссылка на изображение

# %% [markdown]
# ### Описание первого товара
#
#
# Первый товар в предоставленном списке — это парфюмерная вода Liquides Imaginaires DOM ROSA.
#
#
# * Название: Парфюмерная вода | Liquides Imaginaires | DOM ROSA
# * Цена: 10 477
# * Рейтинг: 5.0 (на основе 2 оценок)
# * Бренд: Liquides Imaginaires
# * Ссылка на товар: "/19760302812-dom-rosa"
# * Ссылка на изображение: <https://pcdn.goldapple.ru/p/p/19760302812/web/696d674d61696e8dc83c4ce257069fullhd.jpg>
# * Варианты продукта:
#   * `id`: 19760302812, доступность: доступен, цена: 10 477. Также предоставлены ссылки на товар и изображение.
#   * `id`: 19760302811, доступность: доступен, цена: 15 592. Также предоставлены ссылки на товар и изображение.
#
#
# Товар доступен в 7 категориях, для каждой категории указаны параметры:
# * мужские ароматы (каталог - парфюмерия - нишевая парфюмерия)
#   * `id`: 3784
#   * `link_url`: "/parfjumerija/nishevaja-parfjumerija/muzhskaja-parfjumerija"
#   * `image_url`: "https://pcdn.goldapple.ru/p/p/26374900001/web/696d674d61696e8dc83b5dc894c65fullhd.jpg"
#   * `direct`: false
# * мужские ароматы (каталог - для мужчин - парфюмерия)
# * женские ароматы (каталог - парфюмерия)
# * мужские ароматы (каталог - парфюмерия)
# * парфюмерия (каталог - наша коллекция)
# * нишевая парфюмерия (каталог - для мужчин)
# * женские ароматы (каталог - парфюмерия - нишевая парфюмерия)
